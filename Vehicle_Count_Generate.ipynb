# %%
sc

# %%
volume_rdd = sc.textFile("Traffic_Volume_Counts__2012-2013_.csv", use_unicode=False).cache()
header = volume_rdd.first()

# %%
def format_street_name(name):
    if name == "AVE OF THE AMER":
        return "AVE OF THE AMERICAS"
    number_dict = {'1': 'st', '2': 'nd', '3': 'rd', '11': 'th', '12': 'th', '13': 'th', '14': 'th', '15': 'th', '16': 'th', '17': 'th', '18': 'th', '19': 'th'}
    words = name.split(' ')
    new_string = ""
    for word in words:
        word = word.strip()
        if word.isdigit():
            if len(word) == 1:
                # Single digit number
                new_string += word + number_dict.get(word, 'th') + " "
                
            else:
                # At least two digit number
                last_digit = word[-1]
                last_two_digits = word[-2:]
                new_string += word + number_dict.get(last_two_digits, number_dict.get(last_digit, 'th')) + " "
        else:
            new_string += word + " "
    return new_string

def mapSegmentID(records):
    for record in records:
        if "Segment ID" in record:
            continue
        fields = record.split(',')
        seg_id = fields[1]
        num_vehicles = 0
        
        roadway = format_street_name(fields[2].strip()).strip()
        from_address = format_street_name(fields[3].strip()).strip()
        to_address = format_street_name(fields[4].strip()).strip()
        
        for i in range (7, 31):
            try:
                count = int(fields[i])
                num_vehicles += count
            except ValueError:
                continue
        yield (seg_id, (roadway, from_address, to_address, num_vehicles))  

volume_rdd_seg = volume_rdd.mapPartitions(mapSegmentID)
volume_rdd_seg.collect()
# Out:
# [('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5571)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 4268)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5931)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 6242)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5670)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5361)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 6511)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5687)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 4362)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 6057)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 6401)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5775)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5404)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5341)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 4271)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5635)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5873)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5485)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5440)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5413)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5354)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 4398)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 5260)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 3339)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 3029)),
#  ('2153', ('HUGUENOT AVE', 'WOODROW RD', 'STAFFORD AVE', 2926)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 7277)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 5331)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 5860)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 6387)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 7245)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 7256)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 7996)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 7275)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 5270)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 13742)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 10168)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 11157)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 13391)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 13513)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 13420)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 15766)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 14586)),
#  ('6644', ('RICHMOND HILL ROAD', 'EDINBORO ROAD', 'FOREST HILL ROAD', 11101)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 13767)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 10181)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 13544)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 15885)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 12548)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 13567)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 14763)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 13777)),
#  ('7564', ('MORLEY AVENUE', 'DALTON  AVENUE', 'EBONY STREET', 10292)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4496)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3158)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 2659)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4314)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4310)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4466)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4543)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 4560)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3099)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 2408)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3645)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 2338)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 1971)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3304)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3505)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3857)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3605)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE', 3778)),
#  ('11599', ('OCEAN TERRACE', 'BUTTERWORTH AVENUE', 'COVERLY AVENUE',
),
#  ('25654', ('CONEY ISLAND AVE', 'AVE S', 'AVE T', 11854)),
#  ('25654', ('CONEY ISLAND AVE', 'AVE S', 'AVE T', 13923)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4814)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4816)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5013)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5212)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5449)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5182)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5381)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5282)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4855)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 5193)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4868)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4794)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4925)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4978)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4748)),
#  ('26001', ('AVE U', 'E 16th ST', 'E 17th ST', 4733)),
#  ...]

# %%
def seqOp(seg_dict, tup):
    roadway = tup[0]
    from_address = tup[1]
    to_address = tup[2]
    vehicle_count = tup[3]
    seg_dict['roadway'] = seg_dict.get('roadway', roadway)
    seg_dict['from'] = seg_dict.get('from', from_address)
    seg_dict['to'] = seg_dict.get('to', to_address)
    seg_dict['vehicle_count'] = seg_dict.get('vehicle_count', 0) + vehicle_count
    seg_dict['samples'] = seg_dict.get('samples', 0) + 1
    return seg_dict

def combOp(seg_dict1, seg_dict2):
    seg_dict2['vehicle_count'] += seg_dict1.get('vehicle_count', 0)
    seg_dict2['samples'] += seg_dict1.get('samples', 0)
    return seg_dict2

seg_group_volume_rdd = volume_rdd_seg.aggregateByKey({}, seqOp, combOp)
seg_group_volume_rdd.collect()
# Out:
# [('22379',
#   {'from': 'SMITH STREET',
#    'roadway': '3rd STREET',
#    'samples': 19,
#    'to': 'HOYT STREET',
#    'vehicle_count': 39898}),
#  ('23756',
#   {'from': 'CATHERINE STREET',
#    'roadway': 'MADISON STREET',
#    'samples': 18,
#    'to': 'ST JAMES PLACE',
#    'vehicle_count': 71457}),
#  ('34000',
#   {'from': 'EAST 27th STREET',
#    'roadway': 'MADISON AVENUE',
#    'samples': 8,
#    'to': 'EAST 28th STREET',
#    'vehicle_count': 115100}),
#  ('34257',
#   {'from': 'WEST 61st STREET',
#    'roadway': 'CENTRAL PARK WEST',
#    'samples': 9,
#    'to': 'COLUMBUS CIRCLE',
#    'vehicle_count': 133731}),
#  ('34659',
#   {'from': 'EAST 27th STREET',
#    'roadway': '2nd AVENUE',
#    'samples': 8,
#    'to': 'EAST 28th STREET',
#    'vehicle_count': 695807}),
#  ('91535',
#   {'from': '147th STREET',
#    'roadway': 'ROOSEVELT AVE',
#    'samples': 16,
#    'to': '149th STREET',
#    'vehicle_count': 49029}),
#  ('28997',
#   {'from': '2nd STREET',
#    'roadway': 'PROSPECT PARK WEST',
#    'samples': 10,
#    'to': '3rd STREET',
#    'vehicle_count': 97406}),
#  ('32031',
#   {'from': 'GANSEVOORT STREET',
#    'roadway': 'HUDSON STREET',
#    'samples': 10,
#    'to': 'HORATIO STREET',
#    'vehicle_count': 131372}),
#  ('38619',
#   {'from': 'WEST 123rd ST',
#    'roadway': '8th AVE',
#    'samples': 16,
#    'to': 'WEST 124th ST',
#    'vehicle_count': 100813}),
#  ('20278',
#   {'from': '18th AVENUE',
#    'roadway': '60th STREET',
#    'samples': 20,
#    'to': '19th AVENUE',
#    'vehicle_count': 117883}),
#  ('77328',
#   {'from': 'EAST 160th STREET',
#    'roadway': 'LONGWOOD AVENUE',
#    'samples': 16,
#    'to': 'HEWITT PLACE',
#    'vehicle_count': 33092}),
#  ('56804',
#   {'from': '102nd AVENUE',
#    'roadway': 'VAN WYCK EXPRESSWAY',
#    'samples': 28,
#    'to': 'W 232nd ST',
#    'vehicle_count': 993244}),
#  ('97278',
#   {'from': '189th STREET',
#    'roadway': 'HOLLIS COURT BLVD',
#    'samples': 20,
#    'to': '47th AVE',
#    'vehicle_count': 104172}),
#  ('37362',
#   {'from': 'WEST 99th ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 8,
#    'to': 'WEST 100th ST',
#    'vehicle_count': 150709}),
#  ('72860',
#   {'from': 'WEST 179th STREET',
#    'roadway': 'CEDAR AVENUE',
#    'samples': 20,
#    'to': 'WEST FORDHAM ROAD',
#    'vehicle_count': 46013}),
#  ('176426',
#   {'from': 'EAST FORDHAM ROAD',
#    'roadway': 'CROTONA AVENUE',
#    'samples': 10,
#    'to': 'SOUTHERN BOULEVARD',
#    'vehicle_count': 36066}),
#  ('32932',
#   {'from': 'EAST 12th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 16,
#    'to': 'EAST 13th STREET',
#    'vehicle_count': 250137}),
#  ('6644',
#   {'from': 'EDINBORO ROAD',
#    'roadway': 'RICHMOND HILL ROAD',
#    'samples': 18,
#    'to': 'FOREST HILL ROAD',
#    'vehicle_count': 176741}),
#  ('32585',
#   {'from': 'BROADWAY',
#    'roadway': 'E 4TH ST',
#    'samples': 10,
#    'to': 'LAFAYETTE ST',
#    'vehicle_count': 47810}),
#  ('106931',
#   {'from': 'ST NICHOLAS AVE',
#    'roadway': 'WEST 155th ST',
#    'samples': 16,
#    'to': 'EDGECOMBE AVE',
#    'vehicle_count': 166761}),
#  ('36574',
#   {'from': 'EAST 73rd STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 11,
#    'to': 'EAST 74th STREET',
#    'vehicle_count': 348854}),
#  ('158972',
#   {'from': 'WEST 111th ST',
#    'roadway': 'LENOX AVE',
#    'samples': 18,
#    'to': 'WEST 112th ST',
#    'vehicle_count': 81629}),
#  ('19641',
#   {'from': '72nd STREET',
#    'roadway': '13th AVENUE',
#    'samples': 22,
#    'to': '73rd STREET',
#    'vehicle_count': 73234}),
#  ('19313',
#   {'from': 'W 10th ST',
#    'roadway': 'AVE U',
#    'samples': 20,
#    'to': 'W 11th ST',
#    'vehicle_count': 61776}),
#  ('154613',
#   {'from': 'HAIGHT AVENUE',
#    'roadway': 'ESPLANADE',
#    'samples': 20,
#    'to': 'LURTING AVENUE',
#    'vehicle_count': 13495}),
#  ('157900',
#   {'from': 'LOUISIANA AVE',
#    'roadway': 'FLATLANDS AVE',
#    'samples': 30,
#    'to': 'MALTA ST',
#    'vehicle_count': 405307}),
#  ('43660',
#   {'from': 'BAINBRIDGE STREET',
#    'roadway': 'HOWARD AVENUE',
#    'samples': 8,
#    'to': 'CHAUNCEY STREET',
#    'vehicle_count': 30499}),
#  ('64564',
#   {'from': '198th STREET',
#    'roadway': 'LINDEN BLVD',
#    'samples': 22,
#    'to': '199th STREET',
#    'vehicle_count': 124978}),
#  ('49505',
#   {'from': '78th AVENUE',
#    'roadway': '73rd PLACE',
#    'samples': 18,
#    'to': 'COOPER AVENUE',
#    'vehicle_count': 63750}),
#  ('30790',
#   {'from': 'METROPOLITAN AVE',
#    'roadway': 'BEDFORD AVE',
#    'samples': 14,
#    'to': 'NORTH 1st ST',
#    'vehicle_count': 98018}),
#  ('19463',
#   {'from': '66th STREET',
#    'roadway': '8th AVENUE',
#    'samples': 16,
#    'to': '67th STREET',
#    'vehicle_count': 50925}),
#  ('24988',
#   {'from': 'SHEEPSHEAD BAY RD',
#    'roadway': 'NEPTUNE AVE',
#    'samples': 20,
#    'to': 'W 12th ST',
#    'vehicle_count': 106820}),
#  ('71072',
#   {'from': 'WEST 171st ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 16,
#    'to': 'WEST 172nd ST',
#    'vehicle_count': 135372}),
#  ('22924',
#   {'from': '3rd AVENUE',
#    'roadway': 'ATLANTIC AVENUE',
#    'samples': 20,
#    'to': '4th AVENUE',
#    'vehicle_count': 542255}),
#  ('175696',
#   {'from': 'BRYANT AVENUE',
#    'roadway': 'BRUCKNER BOULEVARD',
#    'samples': 8,
#    'to': 'LONGFELLOW AVENUE',
#    'vehicle_count': 314747}),
#  ('139555',
#   {'from': '58th ST',
#    'roadway': 'PARK AVE',
#    'samples': 18,
#    'to': '59th ST',
#    'vehicle_count': 310596}),
#  ('28021',
#   {'from': 'E 12th ST',
#    'roadway': 'CATON AVE',
#    'samples': 20,
#    'to': 'E 13th ST',
#    'vehicle_count': 130965}),
#  ('38361',
#   {'from': 'WEST 118th ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 16,
#    'to': 'WEST 119th ST',
#    'vehicle_count': 121310}),
#  ('41813',
#   {'from': 'FARRAGUT ROAD',
#    'roadway': 'ALBANY AVENUE',
#    'samples': 16,
#    'to': 'GLENWOOD ROAD',
#    'vehicle_count': 60877}),
#  ('129486',
#   {'from': '205th STREET',
#    'roadway': '115th ROAD',
#    'samples': 22,
#    'to': 'FRANCIS LEWIS BLVD',
#    'vehicle_count': 2849}),
#  ('26001',
#   {'from': 'E 16th ST',
#    'roadway': 'AVE U',
#    'samples': 20,
#    'to': 'E 17th ST',
#    'vehicle_count': 98897}),
#  ('36112',
#   {'from': 'EAST 46th STREET',
#    'roadway': '2nd AVENUE',
#    'samples': 11,
#    'to': 'EAST 47th STREET',
#    'vehicle_count': 550608}),
#  ('38055',
#   {'from': 'EAST 99th ST',
#    'roadway': '2nd AVE',
#    'samples': 8,
#    'to': 'EAST 100th ST',
#    'vehicle_count': 157568}),
#  ('78404',
#   {'from': 'ANTHONY AVENUE',
#    'roadway': 'EAST TREMONT AVENUE',
#    'samples': 20,
#    'to': 'EAST 176th STREET',
#    'vehicle_count': 195125}),
#  ('32787',
#   {'from': 'EAST 11th STREET',
#    'roadway': 'BROADWAY',
#    'samples': 8,
#    'to': 'EAST 12th STREET',
#    'vehicle_count': 187457}),
#  ('69589',
#   {'from': 'CANAL STREET WEST',
#    'roadway': 'EAST 135th STREET',
#    'samples': 8,
#    'to': 'PARK AVENUE',
#    'vehicle_count': 26775}),
#  ('97537',
#   {'from': '194th STREET',
#    'roadway': '56th AVE',
#    'samples': 20,
#    'to': '195th STREET',
#    'vehicle_count': 6571}),
#  ('150677',
#   {'from': 'HINSDALE STREET',
#    'roadway': 'ATLANTIC AVENUE',
#    'samples': 16,
#    'to': 'WILLIAMS AVENUE',
#    'vehicle_count': 137295}),
#  ('17652',
#   {'from': '68th STREET',
#    'roadway': '4th AVENUE',
#    'samples': 20,
#    'to': 'SENATOR STREET',
#    'vehicle_count': 178665}),
#  ('35041',
#   {'from': 'CLAY ST',
#    'roadway': 'COMMERCIAL ST',
#    'samples': 10,
#    'to': 'BOX ST',
#    'vehicle_count': 6445}),
#  ('32095',
#   {'from': 'BROADWAY',
#    'roadway': 'CANAL STREET',
#    'samples': 18,
#    'to': 'CORTLANDT ALLEY',
#    'vehicle_count': 384165}),
#  ('70873',
#   {'from': 'WEST 164th ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 16,
#    'to': 'WEST 165th ST',
#    'vehicle_count': 120934}),
#  ('95270',
#   {'from': '121ST ST',
#    'roadway': 'LEXINGTON AVENUE',
#    'samples': 9,
#    'to': '120TH ST',
#    'vehicle_count': 103979}),
#  ('22409',
#   {'from': 'DE GRAW STREET',
#    'roadway': 'COURT STREET',
#    'samples': 10,
#    'to': 'SACKETT STREET',
#    'vehicle_count': 85829}),
#  ('18846',
#   {'from': 'BAY 46th ST',
#    'roadway': 'SHORE PKWY',
#    'samples': 11,
#    'to': '27th AVE',
#    'vehicle_count': 4671}),
#  ('87459',
#   {'from': 'BRONX PARK EAST',
#    'roadway': 'BOSTON ROAD',
#    'samples': 20,
#    'to': 'PELHAM PARKWAY',
#    'vehicle_count': 230494}),
#  ('33959',
#   {'from': 'WEST 45th STREET',
#    'roadway': '8th AVENUE',
#    'samples': 8,
#    'to': 'WEST 46th STREET',
#    'vehicle_count': 244070}),
#  ('69976',
#   {'from': 'EAST 153rd STREET',
#    'roadway': 'MORRIS AVENUE',
#    'samples': 16,
#    'to': 'EAST 156th STREET',
#    'vehicle_count': 95967}),
#  ('28234',
#   {'from': 'E 18th ST',
#    'roadway': 'CATON AVE',
#    'samples': 20,
#    'to': "ST PAUL'S PL",
#    'vehicle_count': 148920}),
#  ('126531',
#   {'from': 'ANNADALE ROAD',
#    'roadway': 'DRUMGOOLE ROAD WEST',
#    'samples': 9,
#    'to': 'WATKINS AVENUE',
#    'vehicle_count': 29580}),
#  ('158217',
#   {'from': '27th AVE',
#    'roadway': 'CROPSEY AVE',
#    'samples': 22,
#    'to': 'BAY 26th ST',
#    'vehicle_count': 156221}),
#  ('33012',
#   {'from': 'BROADWAY',
#    'roadway': '5th AVENUE',
#    'samples': 8,
#    'to': 'EAST 26th STREET',
#    'vehicle_count': 203468}),
#  ('28403',
#   {'from': 'BEDFORD AVENUE',
#    'roadway': 'FARRAGUT ROAD',
#    'samples': 16,
#    'to': 'EAST 24th STREET',
#    'vehicle_count': 46549}),
#  ('66883',
#   {'from': '55th DR',
#    'roadway': 'MAURICE AVE',
#    'samples': 9,
#    'to': '56th DR',
#    'vehicle_count': 64139}),
#  ('41312',
#   {'from': 'EAST 56th STREET',
#    'roadway': 'AVENUE U',
#    'samples': 16,
#    'to': 'PEARSON STREET',
#    'vehicle_count': 188868}),
#  ('33645',
#   {'from': 'WEST 26th STREET',
#    'roadway': '8th AVENUE',
#    'samples': 8,
#    'to': 'WEST 27th STREET',
#    'vehicle_count': 202574}),
#  ('72608',
#   {'from': 'ACADEMY STREET',
#    'roadway': 'BROADWAY',
#    'samples': 20,
#    'to': 'DYCKMAN STREET',
#    'vehicle_count': 252541}),
#  ('17319',
#   {'from': '7th AVENUE',
#    'roadway': '86th STREET',
#    'samples': 19,
#    'to': '14th AVENUE',
#    'vehicle_count': 222360}),
#  ('72026',
#   {'from': 'EAST 172nd STREET',
#    'roadway': 'JEROME AVENUE',
#    'samples': 16,
#    'to': 'EAST MT EDEN AVENUE',
#    'vehicle_count': 106517}),
#  ('22227',
#   {'from': 'KANE STREET',
#    'roadway': 'HICKS STREET',
#    'samples': 19,
#    'to': 'DE GRAW STREET',
#    'vehicle_count': 108477}),
#  ('102036',
#   {'from': '61st AVE',
#    'roadway': 'MARATHON PKWY',
#    'samples': 20,
#    'to': '63rd AVE',
#    'vehicle_count': 55091}),
#  ('80377',
#   {'from': 'EAST 187th STREET',
#    'roadway': 'CROTONA AVENUE',
#    'samples': 20,
#    'to': 'EAST 189th STREET',
#    'vehicle_count': 81586}),
#  ('21110',
#   {'from': '24th STREET',
#    'roadway': '5th AVENUE',
#    'samples': 20,
#    'to': '36th STREET',
#    'vehicle_count': 93142}),
#  ('22023',
#   {'from': 'DE GRAW STREET',
#    'roadway': 'COLUMBIA STREET',
#    'samples': 20,
#    'to': 'KANE STREET',
#    'vehicle_count': 92637}),
#  ('155773',
#   {'from': '97th ST',
#    'roadway': 'ATLANTIC AVE',
#    'samples': 24,
#    'to': '98th ST',
#    'vehicle_count': 341654}),
#  ('31559',
#   {'from': 'DUANE STREET',
#    'roadway': 'WEST BROADWAY',
#    'samples': 9,
#    'to': 'THOMAS STREET',
#    'vehicle_count': 162047}),
#  ('94154',
#   {'from': 'EAST 177th STREET',
#    'roadway': 'LAFAYETTE AVENUE',
#    'samples': 16,
#    'to': 'HUTCHINSON RIVER PARKWAY',
#    'vehicle_count': 65346}),
#  ('105624',
#   {'from': 'CLEVELAND PLACE',
#    'roadway': 'FINGERBOARD ROAD',
#    'samples': 20,
#    'to': 'COLUMBIA AVENUE',
#    'vehicle_count': 91530}),
#  ('20340',
#   {'from': '72nd ST',
#    'roadway': 'BAY PKWY',
#    'samples': 22,
#    'to': '73rd ST',
#    'vehicle_count': 209803}),
#  ('21327',
#   {'from': '12th AVENUE',
#    'roadway': '39th STREET',
#    'samples': 20,
#    'to': '13th AVENUE',
#    'vehicle_count': 58398}),
#  ('32361',
#   {'from': 'BROADWAY',
#    'roadway': 'BROOME STREET',
#    'samples': 9,
#    'to': 'CROSBY STREET',
#    'vehicle_count': 137935}),
#  ('65745',
#   {'from': '148th ST',
#    'roadway': 'HUNGRY HARBOR RD',
#    'samples': 18,
#    'to': '262nd PL',
#    'vehicle_count': 99203}),
#  ('41736',
#   {'from': 'BROOKLYN AVENUE',
#    'roadway': 'CLARENDON ROAD',
#    'samples': 16,
#    'to': 'EAST 37th STREET',
#    'vehicle_count': 94029}),
#  ('14602',
#   {'from': 'FINGERBOARD ROAD',
#    'roadway': 'HYLAN BOULEVARD',
#    'samples': 19,
#    'to': 'RODERICK AVENUE',
#    'vehicle_count': 28544}),
#  ('72477',
#   {'from': 'WEST 188th STREET',
#    'roadway': 'WADSWORTH AVENUE',
#    'samples': 18,
#    'to': 'WEST 189th STREET',
#    'vehicle_count': 37838}),
#  ('97492',
#   {'from': '200th STREET',
#    'roadway': '35th AVE',
#    'samples': 20,
#    'to': 'CROCHERON AVE',
#    'vehicle_count': 117883}),
#  ('27017',
#   {'from': 'EAST 12th STREET',
#    'roadway': 'AVENUE J',
#    'samples': 16,
#    'to': 'EAST 13th STREET',
#    'vehicle_count': 98962}),
#  ('33652',
#   {'from': 'WEST 27th STREET',
#    'roadway': '7th AVENUE',
#    'samples': 8,
#    'to': 'WEST 28th STREET',
#    'vehicle_count': 233869}),
#  ('152873',
#   {'from': '92nd ST',
#    'roadway': '34th AVE',
#    'samples': 20,
#    'to': '93rd ST',
#    'vehicle_count': 136631}),
#  ('24768',
#   {'from': 'JONES WALK',
#    'roadway': 'SURF AVE',
#    'samples': 20,
#    'to': 'W 10th ST',
#    'vehicle_count': 86491}),
#  ('13133',
#   {'from': 'HOWARD AVENUE',
#    'roadway': 'CLOVE RD',
#    'samples': 20,
#    'to': 'LITTLE CLOVE ROAD',
#    'vehicle_count': 313416}),
#  ('57188',
#   {'from': '101st AVE',
#    'roadway': 'WALTHAM STREET',
#    'samples': 11,
#    'to': 'LIBERTY AVE',
#    'vehicle_count': 32932}),
#  ('31072',
#   {'from': 'UNION AVE',
#    'roadway': 'MONTROSE AVE',
#    'samples': 10,
#    'to': 'LORIME ST',
#    'vehicle_count': 57237}),
#  ('11599',
#   {'from': 'BUTTERWORTH AVENUE',
#    'roadway': 'OCEAN TERRACE',
#    'samples': 20,
#    'to': 'COVERLY AVENUE',
#    'vehicle_count': 68022}),
#  ('120618',
#   {'from': '7th AVE',
#    'roadway': 'CROPSEY AVE',
#    'samples': 22,
#    'to': '14th AVE',
#    'vehicle_count': 115959}),
#  ('34512',
#   {'from': 'WEST 73rd STREET',
#    'roadway': 'AMSTERDAM AVENUE',
#    'samples': 8,
#    'to': 'WEST 74th STREET',
#    'vehicle_count': 206350}),
#  ('158163',
#   {'from': 'BUTLER STREET',
#    'roadway': '4th AVENUE',
#    'samples': 19,
#    'to': 'DOUGLASS STREET',
#    'vehicle_count': 270886}),
#  ('28845',
#   {'from': 'E 37th ST',
#    'roadway': 'CHURCH AVE',
#    'samples': 20,
#    'to': 'BROOKLYN AVE',
#    'vehicle_count': 132333}),
#  ('156204',
#   {'from': 'OLD ROCKAWAY BLVD',
#    'roadway': 'ROCKAWAY BLVD',
#    'samples': 24,
#    'to': 'RADAR RD',
#    'vehicle_count': 550344}),
#  ('73294',
#   {'from': 'W 235th ST',
#    'roadway': 'HENRY HUDSON PKWY',
#    'samples': 36,
#    'to': 'W 236th ST',
#    'vehicle_count': 531781}),
#  ('56994',
#   {'from': 'BRISBIN STREET',
#    'roadway': 'LIBERTY AVE',
#    'samples': 22,
#    'to': 'LLOYD ROAD',
#    'vehicle_count': 248670}),
#  ('150671',
#   {'from': 'ALABAMA AVE',
#    'roadway': 'ATLANTIC AVE',
#    'samples': 28,
#    'to': 'WILLIAMS AVE',
#    'vehicle_count': 378535}),
#  ('31308',
#   {'from': 'THROOP AVE',
#    'roadway': 'MYRTLE AVE',
#    'samples': 28,
#    'to': 'TOMPKINS AVE',
#    'vehicle_count': 147187}),
#  ('51982',
#   {'from': '98th ST',
#    'roadway': 'LIBERTY AVE',
#    'samples': 24,
#    'to': '99th ST',
#    'vehicle_count': 90812}),
#  ('108388',
#   {'from': 'ENGLEWOOD AVENUE',
#    'roadway': 'ARTHUR KILL ROAD',
#    'samples': 18,
#    'to': 'SHARROTTS ROAD',
#    'vehicle_count': 47089}),
#  ('49572',
#   {'from': 'AUTUMN AVENUE',
#    'roadway': 'JAMAICA AVENUE',
#    'samples': 24,
#    'to': 'EUCLID AVENUE',
#    'vehicle_count': 149273}),
#  ('23408',
#   {'from': 'BROADWAY',
#    'roadway': 'CHAMBERS STREET',
#    'samples': 18,
#    'to': 'CENTRE STREET',
#    'vehicle_count': 122519}),
#  ('20335',
#   {'from': 'W 10th ST',
#    'roadway': 'AVE P',
#    'samples': 22,
#    'to': 'W 11th ST',
#    'vehicle_count': 101527}),
#  ('86360',
#   {'from': 'LYDIG AVENUE',
#    'roadway': 'PAULDING AVENUE',
#    'samples': 10,
#    'to': 'NEILL AVENUE',
#    'vehicle_count': 16148}),
#  ('110262',
#   {'from': 'BLOOMFIELD AVENUE',
#    'roadway': 'GLEN STREET',
#    'samples': 10,
#    'to': 'FAHY AVE',
#    'vehicle_count': 49943}),
#  ('158578',
#   {'from': 'EAST 26th STREET',
#    'roadway': 'PARK AVENUE SOUTH',
#    'samples': 16,
#    'to': 'EAST 27th STREET',
#    'vehicle_count': 263450}),
#  ('184562',
#   {'from': 'EAST 172nd STREET',
#    'roadway': 'GRAND CONCOURSE_MAIN',
#    'samples': 32,
#    'to': 'EAST MT EDEN AVENUE',
#    'vehicle_count': 284722}),
#  ('55805',
#   {'from': '111th AVE',
#    'roadway': 'BRINKERHOFF AVE',
#    'samples': 11,
#    'to': '143rd STREET',
#    'vehicle_count': 11913}),
#  ('23396',
#   {'from': 'DUANE STREET',
#    'roadway': 'CHURCH STREET',
#    'samples': 9,
#    'to': 'READE STREET',
#    'vehicle_count': 177911}),
#  ('27121',
#   {'from': 'E 15th ST',
#    'roadway': 'AVE N',
#    'samples': 10,
#    'to': 'E 16th ST',
#    'vehicle_count': 117075}),
#  ('43527',
#   {'from': 'FULTON STREET',
#    'roadway': 'MAC DOUGAL STREET',
#    'samples': 7,
#    'to': 'RALPH AVENUE',
#    'vehicle_count': 4494}),
#  ('21028',
#   {'from': '29th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 9,
#    'to': '28th STREET',
#    'vehicle_count': 152130}),
#  ('154280',
#   {'from': '29th STREET',
#    'roadway': 'GOWANUS EXPRESSWAY',
#    'samples': 10,
#    'to': '28th STREET',
#    'vehicle_count': 681313}),
#  ('34073',
#   {'from': 'BROADWAY',
#    'roadway': '7th AVENUE',
#    'samples': 8,
#    'to': 'WEST 46th STREET',
#    'vehicle_count': 181285}),
#  ('21033',
#   {'from': '28th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 9,
#    'to': '29th STREET',
#    'vehicle_count': 98626}),
#  ('51933',
#   {'from': '95th ST',
#    'roadway': 'PITKIN AVE',
#    'samples': 24,
#    'to': '96th ST',
#    'vehicle_count': 43830}),
#  ('34170',
#   {'from': '5th AVENUE',
#    'roadway': 'WEST 39th STREET',
#    'samples': 8,
#    'to': 'AVE OF THE AMERICAS',
#    'vehicle_count': 88441}),
#  ('88296',
#   {'from': 'FISH AVENUE',
#    'roadway': 'BOSTON ROAD',
#    'samples': 20,
#    'to': 'WILSON AVENUE',
#    'vehicle_count': 204876}),
#  ('69185',
#   {'from': 'EAST 123rd ST',
#    'roadway': '3rd AVE',
#    'samples': 8,
#    'to': 'EAST 124th ST',
#    'vehicle_count': 132538}),
#  ('35672',
#   {'from': 'N. HENRY ST',
#    'roadway': 'GREENPOINT AVE',
#    'samples': 20,
#    'to': 'PROVOST ST',
#    'vehicle_count': 191900}),
#  ('135278',
#   {'from': '67th AVE',
#    'roadway': '164th STREET',
#    'samples': 16,
#    'to': '69th AVE',
#    'vehicle_count': 116340}),
#  ('133984',
#   {'from': 'WEST 148th ST',
#    'roadway': '7th AVE',
#    'samples': 16,
#    'to': 'WEST 149th ST',
#    'vehicle_count': 146263}),
#  ('32066',
#   {'from': 'WALKER STREET',
#    'roadway': 'CORTLANDT ALLEY',
#    'samples': 9,
#    'to': 'WHITE STREET',
#    'vehicle_count': 1313}),
#  ('31890',
#   {'from': 'CHARLTON STREET',
#    'roadway': 'HUDSON STREET',
#    'samples': 10,
#    'to': 'VANDAM STREET',
#    'vehicle_count': 138461}),
#  ('127200',
#   {'from': '19th AVENUE',
#    'roadway': '51st STREET',
#    'samples': 10,
#    'to': '20th AVENUE',
#    'vehicle_count': 13425}),
#  ('7564',
#   {'from': 'DALTON  AVENUE',
#    'roadway': 'MORLEY AVENUE',
#    'samples': 9,
#    'to': 'EBONY STREET',
#    'vehicle_count': 118324}),
#  ('91313',
#   {'from': '37th AVE',
#    'roadway': 'UNION STREET',
#    'samples': 16,
#    'to': '39th AVE',
#    'vehicle_count': 126206}),
#  ('154617',
#   {'from': 'EAST 176th STREET',
#    'roadway': 'BOSTON ROAD',
#    'samples': 16,
#    'to': 'VYSE AVENUE',
#    'vehicle_count': 116308}),
#  ('62171',
#   {'from': 'SAGE ST',
#    'roadway': 'CENTRAL AVE',
#    'samples': 24,
#    'to': 'VIRGINIA ST',
#    'vehicle_count': 135706}),
#  ('27567',
#   {'from': 'AVE P',
#    'roadway': 'NOSTRAND AVE',
#    'samples': 20,
#    'to': 'QUENTIN RD',
#    'vehicle_count': 130685}),
#  ('19991',
#   {'from': '72nd STREET',
#    'roadway': '18th AVENUE',
#    'samples': 20,
#    'to': '73rd STREET',
#    'vehicle_count': 97215}),
#  ('28069',
#   {'from': 'EAST 11th STREET',
#    'roadway': 'CORTELYOU ROAD',
#    'samples': 22,
#    'to': 'EAST 12th STREET',
#    'vehicle_count': 91675}),
#  ('35960',
#   {'from': 'EAST 46th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 11,
#    'to': 'EAST 47th STREET',
#    'vehicle_count': 440770}),
#  ('81165',
#   {'from': 'WEST 259th STREET',
#    'roadway': 'BROADWAY',
#    'samples': 20,
#    'to': 'WEST 260th STREET',
#    'vehicle_count': 179988}),
#  ('28067',
#   {'from': 'EAST 13th STREET',
#    'roadway': 'DITMAS AVENUE',
#    'samples': 22,
#    'to': 'EAST 14th STREET',
#    'vehicle_count': 86950}),
#  ('93757',
#   {'from': 'HARDING AVENUE',
#    'roadway': 'EAST 177th STREET',
#    'samples': 16,
#    'to': 'LAWTON AVENUE',
#    'vehicle_count': 31039}),
#  ('26962',
#   {'from': 'CONEY ISLAND AVE',
#    'roadway': 'AVE P',
#    'samples': 20,
#    'to': 'E 12th ST',
#    'vehicle_count': 183438}),
#  ('20157',
#   {'from': '18th AVENUE',
#    'roadway': '65th STREET',
#    'samples': 20,
#    'to': '19th AVENUE',
#    'vehicle_count': 264481}),
#  ('30633',
#   {'from': 'CLASSON AVE',
#    'roadway': 'LAFAYETTE AVE',
#    'samples': 14,
#    'to': 'FRANKLIN AVE',
#    'vehicle_count': 114573}),
#  ('33612',
#   {'from': 'WEST 43rd STREET',
#    'roadway': '11th AVENUE',
#    'samples': 8,
#    'to': 'WEST 44th STREET',
#    'vehicle_count': 172490}),
#  ('78800',
#   {'from': 'MARMION AVENUE',
#    'roadway': 'E 176th ST',
#    'samples': 9,
#    'to': 'PROSPECT AVENUE',
#    'vehicle_count': 11730}),
#  ('33184',
#   {'from': 'EAST 26th STREET',
#    'roadway': 'LEXINGTON AVENUE',
#    'samples': 8,
#    'to': 'EAST 27th STREET',
#    'vehicle_count': 139493}),
#  ('69154',
#   {'from': 'WEST 147th ST',
#    'roadway': '8th AVE',
#    'samples': 16,
#    'to': 'WEST 148th ST',
#    'vehicle_count': 112925}),
#  ('101855',
#   {'from': 'DEEPDALE AVE',
#    'roadway': 'MARATHON PKWY',
#    'samples': 20,
#    'to': 'RUSHMORE AVE',
#    'vehicle_count': 61309}),
#  ('12945',
#   {'from': 'CAYUGA AVENUE',
#    'roadway': 'LITTLE CLOVE RD',
#    'samples': 10,
#    'to': 'RENWICK AVENUE',
#    'vehicle_count': 63101}),
#  ('23936',
#   {'from': 'MONROE STREET',
#    'roadway': 'CATHERINE STREET',
#    'samples': 9,
#    'to': 'CATHERINE SLIP',
#    'vehicle_count': 34570}),
#  ('174149',
#   {'from': 'GRAND CONCOURSE',
#    'roadway': 'EAST 161st STREET',
#    'samples': 18,
#    'to': 'SHERIDAN AVENUE',
#    'vehicle_count': 115068}),
#  ('33115',
#   {'from': 'EAST 12th STREET',
#    'roadway': '2nd AVENUE',
#    'samples': 8,
#    'to': 'EAST 13th STREET',
#    'vehicle_count': 235072}),
#  ('159216',
#   {'from': 'EAST 59th STREET',
#    'roadway': 'PARK AVENUE',
#    'samples': 22,
#    'to': 'EAST 60th STREET',
#    'vehicle_count': 426488}),
#  ('42542',
#   {'from': 'EAST 78th STREET',
#    'roadway': 'FLATLANDS AVENUE',
#    'samples': 18,
#    'to': 'EAST 79th STREET',
#    'vehicle_count': 238274}),
#  ('148948',
#   {'from': '115th ROAD',
#    'roadway': 'SPRINGFIELD BLVD',
#    'samples': 11,
#    'to': '116th AVE',
#    'vehicle_count': 69947}),
#  ('38035',
#   {'from': 'EAST 99th ST',
#    'roadway': '1st AVE',
#    'samples': 8,
#    'to': 'EAST 97th ST',
#    'vehicle_count': 158478}),
#  ('31148',
#   {'from': 'UNION AVE',
#    'roadway': 'METROPOLITAN AVE',
#    'samples': 18,
#    'to': 'LORIMER ST',
#    'vehicle_count': 134809}),
#  ('72596',
#   {'from': 'VERMILYEA AVENUE',
#    'roadway': 'DYCKMAN STREET',
#    'samples': 18,
#    'to': 'SHERMAN AVENUE',
#    'vehicle_count': 125657}),
#  ('18635',
#   {'from': 'BAY 22nd ST',
#    'roadway': 'CROPSEY AVE',
#    'samples': 22,
#    'to': 'BAY 23rd ST',
#    'vehicle_count': 122177}),
#  ('96042',
#   {'from': '84th AVE',
#    'roadway': 'HOMELAWN STREET',
#    'samples': 16,
#    'to': '84th ROAD',
#    'vehicle_count': 86215}),
#  ('155609',
#   {'from': '221st PLACE',
#    'roadway': 'BRADDOCK AVE',
#    'samples': 22,
#    'to': '221st STREET',
#    'vehicle_count': 105165}),
#  ('41000',
#   {'from': 'EAST 45th STREET',
#    'roadway': 'AVENUE M',
#    'samples': 8,
#    'to': 'EAST 46th STREET',
#    'vehicle_count': 19345}),
#  ('23057',
#   {'from': 'BEAVER STREET',
#    'roadway': 'BROADWAY',
#    'samples': 9,
#    'to': 'MORRIS STREET',
#    'vehicle_count': 128341}),
#  ('69637',
#   {'from': 'GRAND CONCOURSE',
#    'roadway': 'EAST 138th STREET',
#    'samples': 16,
#    'to': 'PARK AVENUE',
#    'vehicle_count': 278756}),
#  ('19566',
#   {'from': '10th AVENUE',
#    'roadway': '65th STREET',
#    'samples': 22,
#    'to': '11th AVENUE',
#    'vehicle_count': 299923}),
#  ('18653',
#   {'from': '19th AVE',
#    'roadway': 'BENSON AVE',
#    'samples': 11,
#    'to': 'BAY 20th ST',
#    'vehicle_count': 21498}),
#  ('38868',
#   {'from': '8th AVENUE',
#    'roadway': 'WEST 135th STREET',
#    'samples': 18,
#    'to': 'EDGECOMBE AVENUE',
#    'vehicle_count': 54533}),
#  ('34013',
#   {'from': '5th AVENUE',
#    'roadway': 'WEST 30th STREET',
#    'samples': 8,
#    'to': 'BROADWAY',
#    'vehicle_count': 58390}),
#  ('158132',
#   {'from': 'LINCOLN AVENUE',
#    'roadway': 'ATLANTIC AVENUE',
#    'samples': 14,
#    'to': 'NICHOLS AVENUE',
#    'vehicle_count': 148661}),
#  ('41864',
#   {'from': 'LENOX RD',
#    'roadway': 'ALBANY AVE',
#    'samples': 20,
#    'to': 'LINDEN BLVD',
#    'vehicle_count': 81835}),
#  ('71591',
#   {'from': 'EAST 156th STREET',
#    'roadway': 'SHERIDAN AVENUE',
#    'samples': 8,
#    'to': 'EAST 161st STREET',
#    'vehicle_count': 46625}),
#  ('19805',
#   {'from': '11th AVENUE',
#    'roadway': '60th STREET',
#    'samples': 22,
#    'to': '12th AVENUE',
#    'vehicle_count': 102189}),
#  ('156336',
#   {'from': '111th AVE',
#    'roadway': 'MERRICK BLVD',
#    'samples': 20,
#    'to': '111th ROAD',
#    'vehicle_count': 218945}),
#  ('32327',
#   {'from': 'BROADWAY',
#    'roadway': 'GRAND STREET',
#    'samples': 9,
#    'to': 'CROSBY STREET',
#    'vehicle_count': 69977}),
#  ('29662',
#   {'from': 'PROSPECT PL',
#    'roadway': 'BEDFORD AVE',
#    'samples': 20,
#    'to': "ST MARK'S AVE",
#    'vehicle_count': 103820}),
#  ('155739',
#   {'from': '115th ROAD',
#    'roadway': 'SPRINGFIELD BLVD',
#    'samples': 11,
#    'to': '116th AVE',
#    'vehicle_count': 77182}),
#  ('29668',
#   {'from': 'LINCOLN PL',
#    'roadway': 'ROGERS AVE',
#    'samples': 10,
#    'to': "ST JOHN'S PL",
#    'vehicle_count': 124872}),
#  ('120740',
#   {'from': 'WEST 103rd ST',
#    'roadway': 'COLUMBUS AVE',
#    'samples': 8,
#    'to': 'WEST 100th ST',
#    'vehicle_count': 107086}),
#  ('27462',
#   {'from': 'AVE R',
#    'roadway': 'BEDFORD AVE',
#    'samples': 20,
#    'to': 'QUENTIN RD',
#    'vehicle_count': 154253}),
#  ('26096',
#   {'from': 'E 15th ST',
#    'roadway': 'AVE Z',
#    'samples': 18,
#    'to': 'E 16th ST',
#    'vehicle_count': 92988}),
#  ('35252',
#   {'from': 'LORIMER ST',
#    'roadway': 'BEDFORD AVE',
#    'samples': 12,
#    'to': 'NORTH 12th ST',
#    'vehicle_count': 62855}),
#  ('42955',
#   {'from': 'MIDWOOD ST',
#    'roadway': 'ALBANY AVE',
#    'samples': 20,
#    'to': 'RUTLAND RD',
#    'vehicle_count': 98654}),
#  ('112431',
#   {'from': 'BALTIC AVENUE',
#    'roadway': 'RICHMOND ROAD',
#    'samples': 10,
#    'to': 'CLOVE ROAD',
#    'vehicle_count': 146487}),
#  ('28612',
#   {'from': 'LENOX RD',
#    'roadway': 'ROGERS AVE',
#    'samples': 10,
#    'to': 'LINDEN BLVD',
#    'vehicle_count': 150003}),
#  ('28973',
#   {'from': '4th AVENUE',
#    'roadway': 'FLATBUSH AVENUE',
#    'samples': 20,
#    'to': 'ROCKWELL PLACE',
#    'vehicle_count': 498024}),
#  ('34124',
#   {'from': 'WEST 61st STREET',
#    'roadway': 'COLUMBUS AVENUE',
#    'samples': 9,
#    'to': 'WEST 62nd STREET',
#    'vehicle_count': 219052}),
#  ('57189',
#   {'from': '146th STREET',
#    'roadway': '101st AVE',
#    'samples': 11,
#    'to': 'WALTHAM STREET',
#    'vehicle_count': 36618}),
#  ('34654',
#   {'from': 'EAST 26th STREET',
#    'roadway': '1st AVENUE',
#    'samples': 8,
#    'to': 'EAST 27th STREET',
#    'vehicle_count': 217731}),
#  ('32706',
#   {'from': '2nd AVENUE',
#    'roadway': 'CHRYSTIE STREET',
#    'samples': 10,
#    'to': 'DELANCEY STREET',
#    'vehicle_count': 81216}),
#  ('18641',
#   {'from': 'BAY 22nd ST',
#    'roadway': 'BATH AVE',
#    'samples': 22,
#    'to': 'BAY 23rd ST',
#    'vehicle_count': 98559}),
#  ('178157',
#   {'from': 'BRUCKNER BOULEVARD',
#    'roadway': 'ZEREGA AVENUE',
#    'samples': 20,
#    'to': 'BRUCKNER EXPRESSWAY',
#    'vehicle_count': 159143}),
#  ('154496',
#   {'from': 'MORRIS AVENUE',
#    'roadway': 'CROSS BRONX EXPRESSWAY',
#    'samples': 12,
#    'to': 'WEEKS AVENUE',
#    'vehicle_count': 858791}),
#  ('164329',
#   {'from': 'BROADWAY',
#    'roadway': 'EAST 18th STREET',
#    'samples': 8,
#    'to': 'PARK AVENUE SOUTH',
#    'vehicle_count': 62241}),
#  ('41546',
#   {'from': 'EAST 66th STREET',
#    'roadway': 'AVENUE U',
#    'samples': 16,
#    'to': 'EAST 67th STREET',
#    'vehicle_count': 69507}),
#  ('71729',
#   {'from': 'EAST 161st STREET',
#    'roadway': 'SHERIDANA AVENUE',
#    'samples': 8,
#    'to': 'EAST 162nd STREET',
#    'vehicle_count': 17557}),
#  ('28855',
#   {'from': 'BROOKLYN AVE',
#    'roadway': 'LINDEN BLVD',
#    'samples': 20,
#    'to': 'E 37th ST',
#    'vehicle_count': 189118}),
#  ('32137',
#   {'from': 'PRINCE STREET',
#    'roadway': 'WEST BROADWAY',
#    'samples': 20,
#    'to': 'SPRING STREET',
#    'vehicle_count': 100135}),
#  ('20561',
#   {'from': '65th STREET',
#    'roadway': '7th AVENUE',
#    'samples': 22,
#    'to': '66th STREET',
#    'vehicle_count': 124264}),
#  ('19813',
#   {'from': '19th AVE',
#    'roadway': '86th ST',
#    'samples': 22,
#    'to': '20th AVE',
#    'vehicle_count': 120959}),
#  ('36579',
#   {'from': 'EAST 73rd STREET',
#    'roadway': '2nd AVENUE',
#    'samples': 11,
#    'to': 'EAST 74th STREET',
#    'vehicle_count': 291615}),
#  ('28620',
#   {'from': 'CLARKSON AVE',
#    'roadway': 'ROGERS AVE',
#    'samples': 10,
#    'to': 'LENOX RD',
#    'vehicle_count': 155090}),
#  ('29696',
#   {'from': 'HANCOCK ST',
#    'roadway': 'BEDFORD AVE',
#    'samples': 9,
#    'to': 'JEFFERSON AVE',
#    'vehicle_count': 150862}),
#  ('76391',
#   {'from': '85th ST',
#    'roadway': '32nd AVE',
#    'samples': 20,
#    'to': '86th ST',
#    'vehicle_count': 59699}),
#  ('43074',
#   {'from': 'LINCOLN PL',
#    'roadway': 'ALBANY AVE',
#    'samples': 10,
#    'to': "ST JOHN'S PL",
#    'vehicle_count': 67032}),
#  ('28103',
#   {'from': 'E 13th ST',
#    'roadway': 'CHURCH AVE',
#    'samples': 20,
#    'to': 'E 14th ST',
#    'vehicle_count': 89792}),
#  ('2153',
#   {'from': 'WOODROW RD',
#    'roadway': 'HUGUENOT AVE',
#    'samples': 26,
#    'to': 'STAFFORD AVE',
#    'vehicle_count': 135004}),
#  ('36803',
#   {'from': 'EAST 74th STREET',
#    'roadway': 'YORK AVENUE',
#    'samples': 20,
#    'to': 'EAST 75th STREET',
#    'vehicle_count': 184703}),
#  ('32449',
#   {'from': 'WEST 11th STREET',
#    'roadway': 'AVENUE OF AMERICAS',
#    'samples': 8,
#    'to': 'WEST 12th STREET',
#    'vehicle_count': 289850}),
#  ('33255',
#   {'from': 'EAST 11th STREET',
#    'roadway': 'AVENUE B',
#    'samples': 18,
#    'to': 'EAST 12th STREET',
#    'vehicle_count': 54771}),
#  ('157736',
#   {'from': 'HASTINGS ST',
#    'roadway': 'ORIENTAL BLVD',
#    'samples': 20,
#    'to': 'GIRARD ST',
#    'vehicle_count': 58317}),
#  ('116416',
#   {'from': 'BOSTON ROAD',
#    'roadway': 'LOUIS NINE  BOULEVARD',
#    'samples': 16,
#    'to': 'EAST 170th STREET',
#    'vehicle_count': 53096}),
#  ('110463',
#   {'from': 'CATHERINE ST',
#    'roadway': 'GRAND AVE',
#    'samples': 24,
#    'to': 'OLIVE ST',
#    'vehicle_count': 165613}),
#  ('37916',
#   {'from': 'EAST 99th ST',
#    'roadway': '3rd AVE',
#    'samples': 8,
#    'to': 'EAST 100th ST',
#    'vehicle_count': 151127}),
#  ('33886',
#   {'from': 'EAST 27th STREET',
#    'roadway': '5th AVENUE',
#    'samples': 8,
#    'to': 'EAST 28th STREET',
#    'vehicle_count': 210003}),
#  ('22921',
#   {'from': 'DEAN STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 20,
#    'to': 'PACIFIC STREET',
#    'vehicle_count': 96499}),
#  ('97387',
#   {'from': '53rd AVE',
#    'roadway': 'UNDERHILL AVE',
#    'samples': 20,
#    'to': '58th AVE',
#    'vehicle_count': 13508}),
#  ('87423',
#   {'from': 'LAURIE AVENUE',
#    'roadway': 'HUTCHINSON RIVER PKWY',
#    'samples': 10,
#    'to': 'ST THERESA AVENUE',
#    'vehicle_count': 21411}),
#  ('67971',
#   {'from': '37th AVE',
#    'roadway': '48th ST',
#    'samples': 20,
#    'to': 'NORTHERN BLVD',
#    'vehicle_count': 77766}),
#  ('174566',
#   {'from': 'FAIRFIELD AVE',
#    'roadway': 'HENRY HUDSON PKWY',
#    'samples': 36,
#    'to': 'W 232nd ST',
#    'vehicle_count': 507349}),
#  ('26932',
#   {'from': 'FOSTER AVENUE',
#    'roadway': 'CONEY ISLAND AVENUE',
#    'samples': 17,
#    'to': 'NEWKIRK AVENUE',
#    'vehicle_count': 199477}),
#  ('155864',
#   {'from': '47th AVE',
#    'roadway': '11th ST',
#    'samples': 20,
#    'to': '47th RD',
#    'vehicle_count': 146462}),
#  ('174218',
#   {'from': 'CARROLL PLACE',
#    'roadway': 'EAST 165th STREET',
#    'samples': 16,
#    'to': 'GRAND CONCOURSE',
#    'vehicle_count': 94906}),
#  ('28637',
#   {'from': 'EAST 28th STREET',
#    'roadway': 'FLATBUSH AVENUE',
#    'samples': 16,
#    'to': 'EAST 29th STREET',
#    'vehicle_count': 224493}),
#  ('33121',
#   {'from': 'EAST 12th STREET',
#    'roadway': '1st AVENUE',
#    'samples': 8,
#    'to': 'EAST 13th STREET',
#    'vehicle_count': 272170}),
#  ('155745',
#   {'from': 'BEACH 7th ST',
#    'roadway': 'SEAGRIT BLVD',
#    'samples': 18,
#    'to': 'BEACH 9th ST',
#    'vehicle_count': 161705}),
#  ('37189',
#   {'from': 'WEST 74th STREET',
#    'roadway': 'CENTRAL PARK WEST',
#    'samples': 16,
#    'to': 'WEST 75th STREET',
#    'vehicle_count': 172545}),
#  ('121069',
#   {'from': 'CLAREMONT PARKWAY',
#    'roadway': 'CROTONA AVENUE',
#    'samples': 16,
#    'to': 'CROTONA PARK NORTH',
#    'vehicle_count': 68981}),
#  ('66455',
#   {'from': '43rd ST',
#    'roadway': '56th RD',
#    'samples': 18,
#    'to': '48th ST',
#    'vehicle_count': 86713}),
#  ('29843',
#   {'from': "ST JOHN'S PL",
#    'roadway': 'BROOKLYN AVE',
#    'samples': 10,
#    'to': 'LINCOLN PL',
#    'vehicle_count': 73936}),
#  ('28732',
#   {'from': 'LENOX RD',
#    'roadway': 'NOSTRAND AVE',
#    'samples': 10,
#    'to': 'LINDEN BLVD',
#    'vehicle_count': 143862}),
#  ('156689',
#   {'from': 'CARPENTER AVE',
#    'roadway': 'JAMAICA AVE',
#    'samples': 11,
#    'to': 'WOODHULL AVE',
#    'vehicle_count': 88199}),
#  ('167027',
#   {'from': 'AVENUE I',
#    'roadway': 'KINGS HIGHWAY',
#    'samples': 32,
#    'to': 'AVENUE J',
#    'vehicle_count': 131134}),
#  ('58320',
#   {'from': '148th ST',
#    'roadway': '150th ST',
#    'samples': 24,
#    'to': 'CENTER CARGO RD',
#    'vehicle_count': 111308}),
#  ('19202',
#   {'from': 'W 11th ST',
#    'roadway': '86th ST',
#    'samples': 20,
#    'to': 'W 12th ST',
#    'vehicle_count': 87862}),
#  ('33547',
#   {'from': 'WEST 25th STREET',
#    'roadway': '9th AVENUE',
#    'samples': 8,
#    'to': 'WEST 26th STREET',
#    'vehicle_count': 301835}),
#  ('28934',
#   {'from': "ST JOHN'S PLACE",
#    'roadway': '6th AVENUE',
#    'samples': 20,
#    'to': 'STERLING PLACE',
#    'vehicle_count': 69886}),
#  ('57192',
#   {'from': '101st AVE',
#    'roadway': 'LIBERTY AVE',
#    'samples': 26,
#    'to': 'WALTHAM STREET',
#    'vehicle_count': 274163}),
#  ('41720',
#   {'from': 'BROOKLYN AVENUE',
#    'roadway': 'AVENUE D',
#    'samples': 16,
#    'to': 'EAST 37th STREET',
#    'vehicle_count': 71033}),
#  ('33796',
#   {'from': 'WEST 26th STREET',
#    'roadway': 'AVENUE OF THE AMERICAS',
#    'samples': 8,
#    'to': 'WEST 27th STREET',
#    'vehicle_count': 291859}),
#  ('71482',
#   {'from': 'SEDGWICK AVENUE',
#    'roadway': 'UNDERCLIFF AVENUE',
#    'samples': 16,
#    'to': 'WEST 171st STREET',
#    'vehicle_count': 66789}),
#  ('129650',
#   {'from': '33rd RD',
#    'roadway': 'VERNON BLVD',
#    'samples': 20,
#    'to': '35th AVE',
#    'vehicle_count': 90155}),
#  ('33305',
#   {'from': 'EAST 27th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 8,
#    'to': 'EAST 28th STREET',
#    'vehicle_count': 247494}),
#  ('41667',
#   {'from': 'EAST 71st STREET',
#    'roadway': 'AVENUE U',
#    'samples': 16,
#    'to': 'EAST 72nd STREET',
#    'vehicle_count': 36558}),
#  ('67724',
#   {'from': 'NORTHERN BLVD',
#    'roadway': '39th ST',
#    'samples': 20,
#    'to': 'SKILLMAN AVE',
#    'vehicle_count': 134857}),
#  ('70892',
#   {'from': 'WEST 166th ST',
#    'roadway': 'AUDUBON AVE',
#    'samples': 16,
#    'to': 'WEST 167th ST',
#    'vehicle_count': 28235}),
#  ('29030',
#   {'from': 'LINCOLN PLACE',
#    'roadway': '7th AVENUE',
#    'samples': 20,
#    'to': "ST JOHN'S PLACE",
#    'vehicle_count': 64235}),
#  ('52940',
#   {'from': '101st ST',
#    'roadway': 'JAMAICA AVE',
#    'samples': 24,
#    'to': '102nd ST',
#    'vehicle_count': 113990}),
#  ('31248',
#   {'from': 'LEONARD  ST',
#    'roadway': 'MESEROLE STREET',
#    'samples': 10,
#    'to': 'LORIMER ST',
#    'vehicle_count': 29659}),
#  ('88927',
#   {'from': 'EAST 233rd STREET',
#    'roadway': 'WEBSTER AVENUE',
#    'samples': 20,
#    'to': 'EAST 234th STREET',
#    'vehicle_count': 163543}),
#  ('111224',
#   {'from': 'WEST 167th ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 16,
#    'to': 'WEST 168th ST',
#    'vehicle_count': 121846}),
#  ('34340',
#   {'from': 'WEST 61st STREET',
#    'roadway': 'AMSTERDAM AVENUE',
#    'samples': 9,
#    'to': 'WEST 62nd STREET',
#    'vehicle_count': 220654}),
#  ('32775',
#   {'from': 'EAST 9th STREET',
#    'roadway': '4th AVENUE',
#    'samples': 8,
#    'to': 'EAST 10th STREET',
#    'vehicle_count': 134971}),
#  ('32364',
#   {'from': 'PRINCE STREET',
#    'roadway': 'BROADWAY',
#    'samples': 9,
#    'to': 'SPRING STREET',
#    'vehicle_count': 183423}),
#  ('32366',
#   {'from': 'BROADWAY',
#    'roadway': 'SPRING STREET',
#    'samples': 9,
#    'to': 'CROSBY STREET',
#    'vehicle_count': 84074}),
#  ('89610',
#   {'from': 'HILL AVENUE',
#    'roadway': 'EAST 241st STREET',
#    'samples': 20,
#    'to': 'MURDOCK AVENUE',
#    'vehicle_count': 38920}),
#  ('23942',
#   {'from': 'CHERRY STREET',
#    'roadway': 'MARKET STREET',
#    'samples': 18,
#    'to': 'SOUTH STREET',
#    'vehicle_count': 35584}),
#  ('40998',
#   {'from': 'BOB STONEHILL WAY',
#    'roadway': 'AVENUE N',
#    'samples': 16,
#    'to': 'EAST 48th STREET',
#    'vehicle_count': 73821}),
#  ('107111',
#   {'from': 'ALDUS STREET',
#    'roadway': 'SOUTHERN BOULEVARD',
#    'samples': 16,
#    'to': 'EAST 163rd STREET',
#    'vehicle_count': 101920}),
#  ('176380',
#   {'from': 'GRAND CONCOURSE',
#    'roadway': 'EAST 204th STREET',
#    'samples': 20,
#    'to': 'VALENTINE AVENUE',
#    'vehicle_count': 22397}),
#  ('157570',
#   {'from': 'LINCOLN AVE',
#    'roadway': 'ATLANTIC AVE',
#    'samples': 15,
#    'to': 'SHERIDAN AVE',
#    'vehicle_count': 183046}),
#  ('32807',
#   {'from': '4th AVENUE',
#    'roadway': 'EAST 14th STREET',
#    'samples': 16,
#    'to': 'BROADWAY',
#    'vehicle_count': 172232}),
#  ('33064',
#   {'from': 'DELANCEY STREET',
#    'roadway': 'CLINTON STREET',
#    'samples': 9,
#    'to': 'RIVINGTON STREET',
#    'vehicle_count': 126278}),
#  ('69276',
#   {'from': 'EAST 124th ST',
#    'roadway': '2nd AVE',
#    'samples': 8,
#    'to': 'EAST 123rd ST',
#    'vehicle_count': 188657}),
#  ('158683',
#   {'from': 'BROADWAY',
#    'roadway': 'EAST HOUSTON STREET',
#    'samples': 18,
#    'to': 'CROSBY STREET',
#    'vehicle_count': 352077}),
#  ('77424',
#   {'from': 'INTERVALE AVENUE',
#    'roadway': 'EAST 163rd STREET',
#    'samples': 16,
#    'to': 'ROGERS PLACE',
#    'vehicle_count': 101989}),
#  ('98876',
#   {'from': '200th STREET',
#    'roadway': '26th AVE',
#    'samples': 20,
#    'to': '202nd STREET',
#    'vehicle_count': 91728}),
#  ('176399',
#   {'from': 'CROTONA PARKWAY',
#    'roadway': 'SOUTHERN BOULEVARD',
#    'samples': 20,
#    'to': 'EAST FORDHAM ROAD',
#    'vehicle_count': 164198}),
#  ('167454',
#   {'from': 'HEGEMAN AVENUE',
#    'roadway': 'ROCKAWAY AVENUE',
#    'samples': 22,
#    'to': 'LINDEN BOULEVARD',
#    'vehicle_count': 109005}),
#  ('41034',
#   {'from': 'EAST 46th STREET',
#    'roadway': 'AVENUE J',
#    'samples': 16,
#    'to': 'SCHENECTADY AVENUE',
#    'vehicle_count': 42497}),
#  ('23061',
#   {'from': 'EDGER ST',
#    'roadway': 'TRINITY PL',
#    'samples': 10,
#    'to': 'RECTOR PL',
#    'vehicle_count': 59454}),
#  ('39011',
#   {'from': 'WEST 147th ST',
#    'roadway': 'AMSTERDAM AVE',
#    'samples': 16,
#    'to': 'WEST 148th ST',
#    'vehicle_count': 129255}),
#  ('33411',
#   {'from': 'WEST 27th STREET',
#    'roadway': '11th AVENUE',
#    'samples': 9,
#    'to': 'WEST 28th STREET',
#    'vehicle_count': 131754}),
#  ('157598',
#   {'from': '28th STREET',
#    'roadway': '4th AVENUE',
#    'samples': 18,
#    'to': '29th STREET',
#    'vehicle_count': 251462}),
#  ('159002',
#   {'from': 'WEST 117th ST',
#    'roadway': '7th AVE',
#    'samples': 30,
#    'to': 'WEST 118th ST',
#    'vehicle_count': 271443}),
#  ('159082',
#   {'from': 'WEST 98th ST',
#    'roadway': 'BROADWAY',
#    'samples': 16,
#    'to': 'WEST 99th ST',
#    'vehicle_count': 166998}),
#  ('158858',
#   {'from': 'WEST 60th STREET',
#    'roadway': 'BROADWAY',
#    'samples': 18,
#    'to': 'WEST 61st STREET',
#    'vehicle_count': 263256}),
#  ('112418',
#   {'from': 'CLOVE ROAD',
#    'roadway': 'LITTLE CLOVE ROAD',
#    'samples': 10,
#    'to': 'ONEIDA AVENUE',
#    'vehicle_count': 52122}),
#  ('164341',
#   {'from': 'DELANCEY STREET',
#    'roadway': 'NORFOLK STREET',
#    'samples': 10,
#    'to': 'RIVINGTON STREET',
#    'vehicle_count': 43658}),
#  ('55804',
#   {'from': '142nd STREET',
#    'roadway': '111th AVE',
#    'samples': 22,
#    'to': '143rd STREET',
#    'vehicle_count': 44541}),
#  ('33471',
#   {'from': 'WEST 27th STREET',
#    'roadway': '10th AVENUE',
#    'samples': 9,
#    'to': 'WEST 28th STREET',
#    'vehicle_count': 244910}),
#  ('23407',
#   {'from': 'DUANE STREET',
#    'roadway': 'BROADWAY',
#    'samples': 10,
#    'to': 'THOMAS STREET',
#    'vehicle_count': 125842}),
#  ('33879',
#   {'from': 'WEST 27th STREET',
#    'roadway': 'BROADWAY',
#    'samples': 8,
#    'to': 'WEST 28th STREET',
#    'vehicle_count': 36804}),
#  ('21331',
#   {'from': '12th AVENUE',
#    'roadway': '37th STREET',
#    'samples': 10,
#    'to': '13th AVENUE',
#    'vehicle_count': 41937}),
#  ('121148',
#   {'from': 'MOSHOLU PARKWAY',
#    'roadway': 'WEST GUN HILL ROAD',
#    'samples': 20,
#    'to': 'WEST MOSHOLU PARKWAY NORTH',
#    'vehicle_count': 139018}),
#  ('126961',
#   {'from': 'WAKEMAN PLACE',
#    'roadway': 'COLONIAL ROAD',
#    'samples': 18,
#    'to': '68th STREET',
#    'vehicle_count': 34476}),
#  ('29014',
#   {'from': 'CARROLL STREET',
#    'roadway': '8th AVENUE',
#    'samples': 10,
#    'to': 'GARFIELD PLACE',
#    'vehicle_count': 77987}),
#  ('154454',
#   {'from': 'MARMION AVENUE',
#    'roadway': 'CROSS BRONX EXPRESSWAY',
#    'samples': 12,
#    'to': 'PROSPECT AVENUE',
#    'vehicle_count': 893281}),
#  ('158203',
#   {'from': 'HINSDALE STREET',
#    'roadway': 'LINDEN BOULEVARD',
#    'samples': 32,
#    'to': 'SNEDIKER AVENUE',
#    'vehicle_count': 477768}),
#  ('56878',
#   {'from': '143rd STREET',
#    'roadway': 'ARCHER AVE',
#    'samples': 22,
#    'to': '144th PLACE',
#    'vehicle_count': 60944}),
#  ('28015',
#   {'from': 'CATON AVE',
#    'roadway': 'CONEY ISLAND AVE',
#    'samples': 20,
#    'to': 'CHURCH AVE',
#    'vehicle_count': 188785}),
#  ('150203',
#   {'from': '115th DRIVE',
#    'roadway': 'FRANCIS LEWIS BLVD',
#    'samples': 22,
#    'to': '115th ROAD',
#    'vehicle_count': 159363}),
#  ('19761',
#   {'from': '72nd STREET',
#    'roadway': '14th AVENUE',
#    'samples': 22,
#    'to': '73rd STREET',
#    'vehicle_count': 74271}),
#  ('91529',
#   {'from': '147th STREET',
#    'roadway': 'SANFORD AVE',
#    'samples': 16,
#    'to': '149th STREET',
#    'vehicle_count': 73817}),
#  ('28923',
#   {'from': 'DE GRAW STREET',
#    'roadway': '5th AVENUE',
#    'samples': 20,
#    'to': 'DOUGLASS STREET',
#    'vehicle_count': 109176}),
#  ('36023',
#   {'from': 'WEST 59th STREET',
#    'roadway': '5th AVENUE',
#    'samples': 9,
#    'to': 'WEST 60th STREET',
#    'vehicle_count': 257499}),
#  ('158764',
#   {'from': 'WEST 122nd ST',
#    'roadway': '7th AVE',
#    'samples': 16,
#    'to': 'WEST 123rd ST',
#    'vehicle_count': 264351}),
#  ('89865',
#   {'from': '136th STREET',
#    'roadway': 'JEWEL AVE',
#    'samples': 16,
#    'to': '138th STREET',
#    'vehicle_count': 107382}),
#  ('32618',
#   {'from': 'EAST 11th STREET',
#    'roadway': '5th AVENUE',
#    'samples': 8,
#    'to': 'EAST 12th STREET',
#    'vehicle_count': 153561}),
#  ('48370',
#   {'from': 'FOUNTAIN AVENUE',
#    'roadway': 'HEGEMAN AVENUE',
#    'samples': 14,
#    'to': 'LOGAN STREET',
#    'vehicle_count': 18961}),
#  ('35178',
#   {'from': 'COMMERCIAL ST',
#    'roadway': 'ASH ST',
#    'samples': 10,
#    'to': 'MC GUINNESS',
#    'vehicle_count': 8813}),
#  ('108716',
#   {'from': 'EAST 120th ST',
#    'roadway': '1st AVE',
#    'samples': 8,
#    'to': 'EAST 124th ST',
#    'vehicle_count': 188888}),
#  ('30645',
#   {'from': 'CLASSON AVE',
#    'roadway': 'MYRTLE AVE',
#    'samples': 20,
#    'to': 'TAAFFE AVE',
#    'vehicle_count': 121923}),
#  ('32443',
#   {'from': 'WEST 12th STREET',
#    'roadway': '7th AVENUE',
#    'samples': 8,
#    'to': 'WEST 13th STREET',
#    'vehicle_count': 279610}),
#  ('33196',
#   {'from': 'DELANCEY STREET',
#    'roadway': 'PITT STREET',
#    'samples': 10,
#    'to': 'STANTON STREET',
#    'vehicle_count': 39870}),
#  ('111646',
#   {'from': 'FARRAGUT ROAD',
#    'roadway': 'NOSTRAND AVENUE',
#    'samples': 8,
#    'to': 'FOSTER AVENUE',
#    'vehicle_count': 58020}),
#  ('73220',
#   {'from': 'INDEPENDENCE AVE',
#    'roadway': 'HENRY HUDSON PKWY',
#    'samples': 36,
#    'to': 'W 232nd ST',
#    'vehicle_count': 526163}),
#  ('56117',
#   {'from': '80th ROAD',
#    'roadway': 'KEW GARDENS ROAD',
#    'samples': 8,
#    'to': 'UNION TURNPIKE',
#    'vehicle_count': 55229}),
#  ('22806',
#   {'from': 'BALTIC STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 20,
#    'to': 'BUTLER STREET',
#    'vehicle_count': 120630}),
#  ('49090',
#   {'from': 'HIGHLAND BOULEVARD',
#    'roadway': 'VERMONT PLACE',
#    'samples': 22,
#    'to': 'JACKIE ROBINSON PKWY',
#    'vehicle_count': 123100}),
#  ('34607',
#   {'from': 'EAST 11th STREET',
#    'roadway': 'AVENUE C',
#    'samples': 18,
#    'to': 'EAST 12th STREET',
#    'vehicle_count': 101882}),
#  ('157659',
#   {'from': 'AUTUMN AVENUE',
#    'roadway': 'LINDEN BOULEVARD',
#    'samples': 22,
#    'to': 'LINCOLN AVENUE',
#    'vehicle_count': 321844}),
#  ('81384',
#   {'from': 'EAST 233rd STREET',
#    'roadway': 'WEBSTER AVENUE',
#    'samples': 20,
#    'to': 'EAST GUN HILL ROAD',
#    'vehicle_count': 83279}),
#  ('132595',
#   {'from': 'EAST 215th STREET',
#    'roadway': 'WHITE PLAINS ROAD',
#    'samples': 20,
#    'to': 'EAST 216th STREET',
#    'vehicle_count': 133832}),
#  ('23207',
#   {'from': 'BROADWAY',
#    'roadway': 'LIBERTY STREET',
#    'samples': 9,
#    'to': 'LIBERTY PLACE',
#    'vehicle_count': 30641}),
#  ('120482',
#   {'from': 'MARISA CIRCLE',
#    'roadway': 'BLOOMINGDALE ROAD',
#    'samples': 18,
#    'to': 'WOODROW ROAD',
#    'vehicle_count': 95944}),
#  ('28262',
#   {'from': 'CATON AVE',
#    'roadway': 'OCEAN AVE',
#    'samples': 20,
#    'to': 'CROOKE AVE',
#    'vehicle_count': 143048}),
#  ('169883',
#   {'from': '30th PL',
#    'roadway': '130th PL',
#    'samples': 20,
#    'to': 'BERGEN RD',
#    'vehicle_count': 79351}),
#  ('179545',
#   {'from': 'HARDING AVENUE',
#    'roadway': 'THROGS NECK EXPRESSWAY',
#    'samples': 28,
#    'to': 'LONGSTREET AVENUE',
#    'vehicle_count': 614969}),
#  ('27139',
#   {'from': 'E 15th ST',
#    'roadway': 'AVE M',
#    'samples': 20,
#    'to': 'ELM AVE',
#    'vehicle_count': 103521}),
#  ('192292',
#   {'from': 'EAST 59th STREET',
#    'roadway': '2nd AVENUE',
#    'samples': 10,
#    'to': 'EAST 60th STREET',
#    'vehicle_count': 974188}),
#  ('158368',
#   {'from': 'NELSON AVENUE',
#    'roadway': 'EDWARD L GRANT HIGHWAY',
#    'samples': 18,
#    'to': 'PLIMPTON AVENUE',
#    'vehicle_count': 258666}),
#  ('155846',
#   {'from': '197th STREET',
#    'roadway': 'JAMAICA AVE',
#    'samples': 10,
#    'to': '198th STREET',
#    'vehicle_count': 85316}),
#  ('32274',
#   {'from': 'HORATIO STREET',
#    'roadway': '8th AVENUE',
#    'samples': 12,
#    'to': 'WEST 4th STREET',
#    'vehicle_count': 205497}),
#  ('110445',
#   {'from': 'GRANITE STREET',
#    'roadway': 'BROADWAY',
#    'samples': 16,
#    'to': 'PILLING STREET',
#    'vehicle_count': 89668}),
#  ('35806',
#   {'from': 'EAST 46th STREET',
#    'roadway': '5th AVENUE',
#    'samples': 11,
#    'to': 'EAST 47th STREET',
#    'vehicle_count': 377573}),
#  ('19244',
#   {'from': 'W 11th ST',
#    'roadway': 'KINGS HWY',
#    'samples': 22,
#    'to': 'W 12th ST',
#    'vehicle_count': 93558}),
#  ('72335',
#   {'from': 'MORRIS AVENUE',
#    'roadway': 'CROSS BX EXPWY SER RD',
#    'samples': 9,
#    'to': 'WEEKS AVENUE',
#    'vehicle_count': 22458}),
#  ('72331',
#   {'from': 'MORRIS AVENUE',
#    'roadway': 'E 174th ST',
#    'samples': 9,
#    'to': 'WEEKS AVENUE',
#    'vehicle_count': 35805}),
#  ('42387',
#   {'from': 'EAST 59th STREET',
#    'roadway': 'GLENWOOD ROAD',
#    'samples': 18,
#    'to': 'RALPH AVENUE',
#    'vehicle_count': 93775}),
#  ('28288',
#   {'from': 'FARRAGUT ROAD',
#    'roadway': 'OCEAN AVENUE',
#    'samples': 16,
#    'to': 'GLENWOOD ROAD',
#    'vehicle_count': 143999}),
#  ('152665',
#   {'from': 'CLASSON AVE',
#    'roadway': 'ATLANTIC AVE',
#    'samples': 20,
#    'to': 'NYCTA SUBWAY',
#    'vehicle_count': 417002}),
#  ('23344',
#   {'from': 'DUTCH STREET',
#    'roadway': 'FULTON STREET',
#    'samples': 9,
#    'to': 'NASSAU STREET',
#    'vehicle_count': 26926}),
#  ('80491',
#   {'from': 'EAST MOSHOLU PARKWAY NORTH',
#    'roadway': 'JEROME AVENUE',
#    'samples': 20,
#    'to': 'MOSHOLU PARKWAY',
#    'vehicle_count': 161530}),
#  ('21148',
#   {'from': '13th AVENUE',
#    'roadway': '50th STREET',
#    'samples': 9,
#    'to': 'New Utrecht Avenue',
#    'vehicle_count': 27956}),
#  ('70931',
#   {'from': 'WEST 172nd ST',
#    'roadway': 'AUDUBON AVE',
#    'samples': 18,
#    'to': 'WEST 173rd ST',
#    'vehicle_count': 46264}),
#  ('164301',
#   {'from': 'DELANCEY STREET',
#    'roadway': 'ALLEN STREET',
#    'samples': 20,
#    'to': 'RIVINGTON STREET',
#    'vehicle_count': 209250}),
#  ('22219',
#   {'from': 'SACKETT STREET',
#    'roadway': 'CLINTON STREET',
#    'samples': 9,
#    'to': 'UNION STREET',
#    'vehicle_count': 38784}),
#  ('109335',
#   {'from': 'THORNTON ST',
#    'roadway': 'FLUSHING AVE',
#    'samples': 20,
#    'to': 'WHIPPLE ST',
#    'vehicle_count': 136159}),
#  ('21142',
#   {'from': '13th AVENUE',
#    'roadway': '51st STREET',
#    'samples': 9,
#    'to': 'New Utrecht Avenue',
#    'vehicle_count': 25757}),
#  ('27106',
#   {'from': 'E 15th ST',
#    'roadway': 'KINGS HWY',
#    'samples': 20,
#    'to': 'E 16th ST',
#    'vehicle_count': 137950}),
#  ('65634',
#   {'from': '107th AVENUE',
#    'roadway': 'CROSS ISLAND PKWY SR',
#    'samples': 31,
#    'to': '115th AVENUE',
#    'vehicle_count': 1199066}),
#  ('109816',
#   {'from': '67th STREET',
#    'roadway': '10th AVENUE',
#    'samples': 20,
#    'to': '68th STREET',
#    'vehicle_count': 58139}),
#  ('33758',
#   {'from': 'WEST 45th STREET',
#    'roadway': '10th AVENUE',
#    'samples': 8,
#    'to': 'WEST 46th STREET',
#    'vehicle_count': 284003}),
#  ('32698',
#   {'from': 'EAST HOUSTON STREET',
#    'roadway': 'BOWERY',
#    'samples': 10,
#    'to': 'PRINCE STREET',
#    'vehicle_count': 178643}),
#  ('78805',
#   {'from': 'MARMION AVENUE',
#    'roadway': 'FAIRMONT PL',
#    'samples': 9,
#    'to': 'PROSPECT AVENUE',
#    'vehicle_count': 8694}),
#  ('179547',
#   {'from': 'HARDING AVENUE',
#    'roadway': 'THROGS NECK EXPWY SER RD',
#    'samples': 9,
#    'to': 'LONGSTREET AVENUE',
#    'vehicle_count': 15335}),
#  ('36162',
#   {'from': 'EAST 59th STREET',
#    'roadway': 'MADISON AVENUE',
#    'samples': 8,
#    'to': 'EAST 60th STREET',
#    'vehicle_count': 201332}),
#  ('34188',
#   {'from': 'WEST 45th STREET',
#    'roadway': 'AVENUE OF THE AMERICAS',
#    'samples': 8,
#    'to': 'WEST 46th STREET',
#    'vehicle_count': 255400}),
#  ('57167',
#   {'from': 'INWOOD STREET',
#    'roadway': 'LAKEWOOD AVE',
#    'samples': 14,
#    'to': 'LIVERPOOL STREET',
#    'vehicle_count': 25115}),
#  ('25654',
#   {'from': 'AVE S',
#    'roadway': 'CONEY ISLAND AVE',
#    'samples': 20,
#    'to': 'AVE T',
#    'vehicle_count': 253002}),
#  ('70939',
#   {'from': 'WEST 174th ST',
#    'roadway': 'BROADWAY',
#    'samples': 19,
#    'to': 'WEST 175th ST',
#    'vehicle_count': 167806}),
#  ('27344',
#   {'from': 'AVE R',
#    'roadway': 'OCEAN AVE',
#    'samples': 20,
#    'to': 'AVE S',
#    'vehicle_count': 212650}),
#  ('33891',
#   {'from': '5th AVENUE',
#    'roadway': 'WEST 29th STREET',
#    'samples': 8,
#    'to': 'BROADWAY',
#    'vehicle_count': 76020}),
#  ('159183',
#   {'from': 'WEST 74th STREET',
#    'roadway': 'BROADWAY',
#    'samples': 16,
#    'to': 'WEST 75th STREET',
#    'vehicle_count': 336254}),
#  ('28370',
#   {'from': 'CATON AVE',
#    'roadway': 'FLATBUSH AVE',
#    'samples': 20,
#    'to': 'CLARKSON AVE',
#    'vehicle_count': 242479}),
#  ('34027',
#   {'from': '5th AVENUE',
#    'roadway': 'WEST 34th STREET',
#    'samples': 16,
#    'to': 'AVE OF THE AMERICAS',
#    'vehicle_count': 190774}),
#  ('151662',
#   {'from': '97th AVE',
#    'roadway': 'WOODHAVEN BLVD',
#    'samples': 36,
#    'to': '101st ST',
#    'vehicle_count': 425356}),
#  ('165258',
#   {'from': 'LEONARD ST',
#    'roadway': 'MEEKER AVE',
#    'samples': 20,
#    'to': 'WITHERS ST',
#    'vehicle_count': 148009}),
#  ('38489',
#   {'from': 'WEST 119th STREET',
#    'roadway': 'MANHATTAN AVENUE',
#    'samples': 18,
#    'to': 'WEST 120th STREET',
#    'vehicle_count': 37488}),
#  ('32126',
#   {'from': 'VANDAM STREET',
#    'roadway': 'AVENUE OF THE AMERICAS',
#    'samples': 10,
#    'to': 'SPRING STREET',
#    'vehicle_count': 251397}),
#  ('33848',
#   {'from': 'WEST 45th STREET',
#    'roadway': '9th AVENUE',
#    'samples': 8,
#    'to': 'WEST 46th STREET',
#    'vehicle_count': 258545}),
#  ('29470',
#   {'from': 'GATES AVE',
#    'roadway': 'CLASSON AVE',
#    'samples': 10,
#    'to': 'PUTNAM AVE',
#    'vehicle_count': 67116}),
#  ('36674',
#   {'from': 'EAST 73rd STREET',
#    'roadway': '1st AVENUE',
#    'samples': 11,
#    'to': 'EAST 74th STREET',
#    'vehicle_count': 344844}),
#  ('37374',
#   {'from': 'EAST 73rd STREET',
#    'roadway': '5th AVENUE',
#    'samples': 10,
#    'to': 'EAST 74th STREET',
#    'vehicle_count': 173410}),
#  ('36403',
#   {'from': 'EAST 60th STREET',
#    'roadway': '1st AVENUE',
#    'samples': 11,
#    'to': 'EAST 61st STREET',
#    'vehicle_count': 199442}),
#  ('36272',
#   {'from': 'EAST 59th STREET',
#    'roadway': '3rd AVENUE',
#    'samples': 11,
#    'to': 'EAST 60th STREET',
#    'vehicle_count': 290913}),
#  ('37277',
#   {'from': 'WEST 97th STREET',
#    'roadway': 'WEST END AVENUE',
#    'samples': 16,
#    'to': 'WEST 98th STREET',
#    'vehicle_count': 97645}),
#  ('54575',
#   {'from': 'COHANCY ST',
#    'roadway': 'SOUTH CONDUIT AVE',
#    'samples': 12,
#    'to': 'NASSAU EXPY',
#    'vehicle_count': 493827}),
#  ('101614',
#   {'from': 'DOUGLASTON PKWY',
#    'roadway': 'MARYLAND RD',
#    'samples': 16,
#    'to': 'HANFORD ST',
#    'vehicle_count': 1509}),
#  ('158582',
#   {'from': 'WEST 148th ST',
#    'roadway': 'BROADWAY',
#    'samples': 16,
#    'to': 'WEST 149th ST',
#    'vehicle_count': 187877}),
#  ('19437',
#   {'from': '11TH AVE',
#    'roadway': 'BAY RIDGE PKWY',
#    'samples': 20,
#    'to': '12TH AVE',
#    'vehicle_count': 171369}),
#  ('35257',
#   {'from': 'LORIMER ST',
#    'roadway': 'DRIGGS AVE',
#    'samples': 14,
#    'to': 'NORTH 12th ST',
#    'vehicle_count': 72555}),
#  ('28976',
#   {'from': '4th AVENUE',
#    'roadway': 'ASHLAND PLACE',
#    'samples': 20,
#    'to': 'LAFAYETTE AVENUE',
#    'vehicle_count': 63523}),
#  ('158964',
#   {'from': 'WEST 123rd ST',
#    'roadway': 'LENOX AVE',
#    'samples': 16,
#    'to': 'WEST 124th ST',
#    'vehicle_count': 153417}),
#  ('21399',
#   {'from': '36th STREET',
#    'roadway': 'FT HAMILTON PARKWAY',
#    'samples': 20,
#    'to': 'CHESTER AVENUE',
#    'vehicle_count': 255198})]

# %%
from geopy.geocoders import Nominatim

def geomMap(records):
    geolocator = Nominatim(format_string="%s, NY", country_bias="USA", timeout=10)
    for record in records:
        print record
        print ("______________")
        seg_id = record[0]
        from_address = record[1]['from'].strip()
        to_address = record[1]['to'].strip()
        roadway = record[1]['roadway'].strip()
        vehicle_count = record[1]['vehicle_count']
        samples = record[1]['samples']
        
        try:
            roadway_dict = geolocator.geocode(roadway, addressdetails=True).raw
            from_dict    = geolocator.geocode(from_address, addressdetails=True).raw
            to_dict      = geolocator.geocode(to_address, addressdetails=True).raw
        except AttributeError:
            # Couldn't geolocate, skip this record
            print ("SKIPPING {}".format(record))
            print("__________")
            continue
        
        try:
            roadway_address = roadway_dict['address']
            from_address    = from_dict['address']
            to_address      = to_dict['address']
        except:
            # No address field, skip this record
            print ("SKIPPING {}".format(record))
            print("__________")
            continue
        
        try:
            roadway_postcode = roadway_address['postcode'].strip()
            from_postcode = from_address['postcode'].strip()
            to_postcode = to_address['postcode'].strip()
        except:
            # No postcode field, skip this record
            print ("SKIPPING {}".format(record))
            print("__________")
            continue
        
        from_postcode_count = vehicle_count
        to_postcode_count = vehicle_count
        half_vehicle_count = vehicle_count / 2
        one_third_vehicle_count = vehicle_count / 3
        two_third_vehicle_count = 2 * one_third_vehicle_count
        half_samples = samples / 2
        one_third_samples = samples / 3
        two_third_samples = 2 * one_third_samples
        
        if from_postcode != to_postcode:
            if roadway_postcode == from_postcode:
                yield(from_postcode, two_third_vehicle_count, two_third_samples)
                yield(to_postcode, one_third_vehicle_count, one_third_samples)
            elif roadway_postcode == to_postcode:
                to_postcode_count = two_third_vehicle_count
                from_postcode_count = one_third_vehicle_count
                
                yield(from_postcode, one_third_vehicle_count, one_third_samples)
                yield(to_postcode, two_third_vehicle_count, two_third_samples)
            else:
                to_postcode_count = one_third_vehicle_count
                from_postcode_count = one_third_vehicle_count
                roadway_postcode_count = one_third_vehicle_count
                
                yield(from_postcode, one_third_vehicle_count, one_third_samples)
                yield(to_postcode, one_third_vehicle_count, one_third_samples)
                yield(roadway_postcode, one_third_vehicle_count, one_third_samples)
        else:
            # From and to postcode's agree
            if roadway_postcode == from_postcode:
                # All three agree
                yield(roadway_postcode, vehicle_count, samples)
            else:
                # Only from and to agree
                yield(from_postcode, two_third_vehicle_count, two_third_samples)
                yield(roadway_postcode, one_third_vehicle_count, one_third_samples)
        
def toCSVLine(data):
    return ','.join(str(d) for d in data)    
    
    
seg_group_volume_rdd.mapPartitions(geomMap).map(toCSVLine).coalesce(1).saveAsTextFile("./Raw Result/vehicle_results")
